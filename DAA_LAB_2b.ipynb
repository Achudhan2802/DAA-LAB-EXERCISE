# %% [markdown]
# <a href="https://colab.research.google.com/github/Achudhan2802/DAA-LAB-EXERCISE/blob/main/DAA_LAB_2b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def compute_lps(pattern):
    m = len(pattern)
    lps = [0] * m

    length = 0
    i = 1

    while i < m:
        if pattern[i] == pattern[length]:
            length += 1
            lps[i] = length
            i += 1
        else:
            if length != 0:
                length = lps[length - 1]
            else:
                lps[i] = 0
                i += 1

    return lps


def kmp_search(text, pattern):
    n = len(text)
    m = len(pattern)

    lps = compute_lps(pattern)

    print("Text    :", text)
    print("Pattern :", pattern)
    print("LPS Array:", lps)
    print()

    i = 0  # index for text
    j = 0  # index for pattern

    while i < n:
        if pattern[j] == text[i]:
            i += 1
            j += 1

        if j == m:
            print("Pattern found at index", i - j)
            j = lps[j - 1]

        elif i < n and pattern[j] != text[i]:
            print(f"Mismatch at Text[{i}]='{text[i]}' and Pattern[{j}]='{pattern[j]}'")

            if j != 0:
                print(f"Shift pattern using LPS: j = {lps[j-1]}")
                j = lps[j - 1]
            else:
                print("Move to next character in text")
                i += 1


# Given input
text = "AABCAABXAAAZ"
pattern = "AABXAA"

kmp_search(text, pattern)
# Out:
# Text    : AABCAABXAAAZ
# Pattern : AABXAA
# LPS Array: [0, 1, 0, 0, 1, 2]
#
# Mismatch at Text[3]='C' and Pattern[3]='X'
# Shift pattern using LPS: j = 0
# Mismatch at Text[3]='C' and Pattern[0]='A'
# Move to next character in text
# Pattern found at index 4
# Mismatch at Text[10]='A' and Pattern[2]='B'
# Shift pattern using LPS: j = 1
# Mismatch at Text[11]='Z' and Pattern[2]='B'
# Shift pattern using LPS: j = 1
# Mismatch at Text[11]='Z' and Pattern[1]='A'
# Shift pattern using LPS: j = 0
# Mismatch at Text[11]='Z' and Pattern[0]='A'
# Move to next character in text
